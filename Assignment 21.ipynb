# %% [markdown]
# #### Ans1.
# Add the current date to the text file `today.txt` as a string.
#
# ```python
# from datetime import date
#
# current_date = date.today()
# with open('today.txt', 'w') as file:
#     file.write(str(current_date))
# ```
#
# #### Ans2.
# Read the text file `today.txt` into the string `today_string`.
#
# ```python
# with open('today.txt', 'r') as file:
#     today_string = file.read()
# print(today_string)
# ```
#
# #### Ans3.
# Parse the date from `today_string`.
#
# ```python
# from datetime import datetime
#
# parsed_date = datetime.strptime(today_string, '%Y-%m-%d').date()
# print(parsed_date)
# ```
#
# #### Ans4.
# List the files in your current directory.
#
# ```python
# import os
#
# current_directory = os.getcwd()
# files_in_directory = os.listdir(current_directory)
# print(files_in_directory)
# ```
#
# #### Ans5.
# Create a list of all of the files in your parent directory (minimum five files should be available).
#
# ```python
# parent_directory = os.path.abspath('..')
# files_in_parent_directory = os.listdir(parent_directory)
# print(files_in_parent_directory)
# ```
#
# #### Ans6.
# Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.
#
# ```python
# import multiprocessing
# import random
# import time
# from datetime import datetime
#
# def print_current_time():
#     wait_time = random.randint(1, 5)
#     time.sleep(wait_time)
#     current_time = datetime.now().strftime('%H:%M:%S')
#     print(f"Current time: {current_time}")
#
# if __name__ == "__main__":
#     for _ in range(3):
#         process = multiprocessing.Process(target=print_current_time)
#         process.start()
# ```
#
# #### Ans7.
# Create a date object of your day of birth.
#
# ```python
# from datetime import date
#
# day_of_birth = date(2000, 5, 15)  # Replace with your actual day of birth
# print(day_of_birth)
# ```
#
# #### Ans8.
# What day of the week was your day of birth?
#
# ```python
# weekday_of_birth = day_of_birth.strftime('%A')
# print(weekday_of_birth)
# ```
#
# #### Ans9.
# When will you be (or when were you) 10,000 days old?
#
# ```python
# from datetime import timedelta
#
# age_in_days = 10000
# future_date = day_of_birth + timedelta(days=age_in_days)
# print(future_date)
# ```
